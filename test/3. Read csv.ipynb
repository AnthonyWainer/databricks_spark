# %% [markdown]
# # Question 3

# %% [markdown]
# Question 3: You are working as a Data Engineer in Bluetab. And you know all the files
# generated by your source systems are in csv format only. Hence, you want that the object's load
# method should expect csv file only in case of below line is executed.

# %%
from pyspark.sql import Row
from pyspark.sql.session import SparkSession
spark = SparkSession.builder.master("local[*]").appName("jdbc data sources").getOrCreate()

# %%
#course = spark.read.load("tmp/dataframe_sample.csv")
spark.read.format("csv").load("tmp/dataframe_sample.csv")
# Out:
# DataFrame[_c0: string]

# %% [markdown]
# Hence, which of the following property you will update, so that default load method will always consider
# input file as csv, unless specifically format is called?

# %% [markdown]
# #### In the simplest form, the default data source (parquet unless otherwise configured by spark.sql.sources.default) will be used for all operations.
